# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\python DA\country_wise_latest.csv")

# %%
data
# Out:
#                 Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.count()

#null values means missing values
# Out:
# Country                   187
# Confirmed                 187
# Deaths                    187
# Recovered                 187
# Active                    187
# New cases                 187
# New deaths                187
# New recovered             187
# Deaths / 100 Cases        187
# Recovered / 100 Cases     187
# Deaths / 100 Recovered    187
# Confirmed last week       187
# 1 week change             187
# 1 week % increase         187
# WHO Region                187
# dtype: int64

# %%
data.isnull()   

# false = no null value , true = having null valuess
# Out:
#      Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0      False      False   False      False   False      False       False
# 1      False      False   False      False   False      False       False
# 2      False      False   False      False   False      False       False
# 3      False      False   False      False   False      False       False
# 4      False      False   False      False   False      False       False
# ..       ...        ...     ...        ...     ...        ...         ...
# 182    False      False   False      False   False      False       False
# 183    False      False   False      False   False      False       False
# 184    False      False   False      False   False      False       False
# 185    False      False   False      False   False      False       False
# 186    False      False   False      False   False      False       False
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.isnull().sum()
# Out:
# Country                   0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())

plt.show()

# %%
#showing the number of confirmed, Deaths and Recovered Cases in each Region.

data.head(2)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.groupby('Country').sum().head(20)  # combination of splitting the object, apply function, combining the result
# Out:
#                      Confirmed  Deaths  Recovered  Active  New cases  \
# Country
# Afghanistan              36263    1269      25198    9796        106
# Albania                   4880     144       2745    1991        117
# Algeria                  27973    1163      18837    7973        616
# Andorra                    907      52        803      52         10
# Angola                     950      41        242     667         18
# Antigua and Barbuda         86       3         65      18          4
# Argentina               167416    3059      72575   91782       4890
# Armenia                  37390     711      26665   10014         73
# Australia                15303     167       9311    5825        368
# Austria                  20558     713      18246    1599         86
# Azerbaijan               30446     423      23242    6781        396
# Bahamas                    382      11         91     280         40
# ...

# %%
data.groupby('Country')['Confirmed'].sum().sort_values(ascending = False).head(10)
# Out:
# Country
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Name: Confirmed, dtype: int64

# %%
data.groupby('Country')['Confirmed'].sum()  # cant handle more than 1 element
# Out:
# Country
# Afghanistan           36263
# Albania                4880
# Algeria               27973
# Andorra                 907
# Angola                  950
#                       ...
# West Bank and Gaza    10621
# Western Sahara           10
# Yemen                  1691
# Zambia                 4552
# Zimbabwe               2704
# Name: Confirmed, Length: 187, dtype: int64

# %%
#Removing all the records where Confirmed cases is less than 1000

data = data[~(data.Confirmed < 1000)] # to remove the records satisfying a particular condition

# %%
data
# Out:
#                 Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# ..                  ...        ...     ...        ...     ...        ...
# 180           Venezuela      15988     146       9959    5883        525
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
# in which region maximum number of confirmed cases were recorded?

data.groupby('Country').Confirmed.sum().sort_values(ascending = False).head(10)
# Out:
# Country
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Name: Confirmed, dtype: int64

# %%
# in which region minimum number of deaths cases were recorded?

data.head(2)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.groupby('Country').Deaths.sum().sort_values(ascending = True).head(20)
# Out:
# Country
# Uganda            2
# Rwanda            5
# Namibia           8
# Iceland          10
# Mozambique       11
# Jordan           11
# Sri Lanka        11
# Maldives         15
# Georgia          16
# Cyprus           19
# New Zealand      22
# Cabo Verde       22
# Suriname         24
# Guinea-Bissau    26
# Singapore        27
# Slovakia         28
# Latvia           31
# Eswatini         34
# Benin            35
# Uruguay          35
# Name: Deaths, dtype: int64

# %%
#how many confirmed deaths and confirmed and recovered cases were reported from india 

data.head(2)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data[data.Country == 'India']
# Out:
#    Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 79   India    1480073   33408     951166  495499      44457         637
#
#     New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 79          33598                2.26                  64.26
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 79                    3.51              1155338         324735
#
#     1 week % increase       WHO Region
# 79              28.11  South-East Asia

# %%
data[data.Country == 'Yemen']
# Out:
#     Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 184   Yemen       1691     483        833     375         10           4
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 184             36               28.56                  49.26
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 184                   57.98                 1619             72
#
#      1 week % increase             WHO Region
# 184               4.45  Eastern Mediterranean

# %%
data[data.Country == 'US']
# Out:
#     Country  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 173      US    4290259  148011    1325804  2816444      56336        1076
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173          27941                3.45                   30.9
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region
# 173              11.88   Americas

# %%
#sort the entire data wrt number of confirmed cases in ascending order

data.head(2)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.sort_values( by = ['Confirmed'], ascending = True).head(10)
# Out:
#           Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 45         Cyprus       1060      19        852     189          3
# 26   Burkina Faso       1100      53        926     121         14
# 174        Uganda       1128       2        986     140         13
# 123         Niger       1132      69       1027      36          0
# 64        Georgia       1137      16        922     199          6
# 98        Liberia       1167      72        646     449          5
# 88         Jordan       1176      11       1041     124          8
# 178       Uruguay       1202      35        951     216         10
# 95         Latvia       1219      31       1045     143          0
# 171       Tunisia       1455      50       1157     248          3
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 45            0              0                1.79                  80.38
# 26            0              6                4.82                  84.18
# ...

# %%
#sort the entire data wrt no. of recovered cases in descending order

data.head(2)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.sort_values(by = ['Recovered'],ascending = False).head(10)
# Out:
#           Country  Confirmed  Deaths  Recovered   Active  New cases  \
# 23         Brazil    2442375   87618    1846641   508116      23284
# 173            US    4290259  148011    1325804  2816444      56336
# 79          India    1480073   33408     951166   495499      44457
# 138        Russia     816680   13334     602249   201097       5607
# 35          Chile     347923    9187     319954    18782       2133
# 111        Mexico     395489   44022     303810    47657       4973
# 154  South Africa     452529    7067     274925   170537       7096
# 132          Peru     389717   18418     272547    98752      13756
# 81           Iran     293606   15912     255144    22550       2434
# 128      Pakistan     274289    5842     241026    27421       1176
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 23          614          33728                3.59                  75.61
# ...
